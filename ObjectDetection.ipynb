# %% [markdown]
# <a href="https://colab.research.google.com/github/AutonomeStudienarbeit/Notebooks/blob/main/ObjectDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Object Detection with YOLO
# ------------------------------
# ## Install the darknet Framework

# %%
# !git clone https://github.com/pjreddie/darknet.git
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 5940, done.
# remote: Total 5940 (delta 0), reused 0 (delta 0), pack-reused 5940
# Receiving objects: 100% (5940/5940), 6.36 MiB | 16.13 MiB/s, done.
# Resolving deltas: 100% (3937/3937), done.

# %%
# !nvidia-smi
# %cd ./darknet
#!sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# !make
# Out:
# Fri Nov  5 08:31:23 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8    27W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !ls
# !wget https://pjreddie.com/media/files/yolov3.weights

# %%
# !./darknet
# !./darknet detect cfg/yolov3.cfg yolov3.weights data/dog.jpg -dont_show
# Out:
# backup	 examples	LICENSE       LICENSE.meta  obj        scripts
# cfg	 include	LICENSE.fuck  LICENSE.mit   python     src
# darknet  libdarknet.a	LICENSE.gen   LICENSE.v1    README.md  yolov3.weights
# data	 libdarknet.so	LICENSE.gpl   Makefile	    results
# --2021-11-05 08:56:21--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights.1’
#
# yolov3.weights.1    100%[===================>] 236.52M  52.6MB/s    in 4.7s
#
# 2021-11-05 08:56:26 (50.8 MB/s) - ‘yolov3.weights.1’ saved [248007048/248007048]
#
# usage: ./darknet <function>
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  32  0.639 BFLOPs
# ...
